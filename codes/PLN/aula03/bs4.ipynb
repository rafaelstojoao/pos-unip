# %%
# !pip3 install bs4
from bs4 import BeautifulSoup

# from urllib.request import urlopen
import requests

# %%
link = 'https://g1.globo.com/loterias/noticia/2020/10/07/mega-sena-concurso-2306-resultado.ghtml'
link2 = 'https://www.hojemais.com.br/aracatuba/noticia/cotidiano/aracatuba-tem-aumento-de-74-nos-casos-de-covid19-na-semana'
# html = urlopen(link)
link3 = 'https://g1.globo.com/loterias/'

link4 = 'https://www.google.com/search?q=lego'
page = requests.get(link4)


pagina = BeautifulSoup(page.content,'html')
print(pagina.title)
# Out:
# <title>lego - Pesquisa Google</title>

# %%
print(pagina.find_all('a'))
# Out:
# [<a href="/?sa=X&amp;ved=0ahUKEwin3uL0hqrsAhWWHbkGHRDoDc4QOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a>, <a class="l" href="/?output=search&amp;ie=UTF-8&amp;sa=X&amp;ved=0ahUKEwin3uL0hqrsAhWWHbkGHRDoDc4QPAgE"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a>, <a href="/search?q=lego&amp;ie=UTF-8&amp;gbv=1&amp;sei=xqyBX6fjIZa75OUPkNC38Aw">aqui</a>, <a class="eZt8xd" href="/search?q=lego&amp;ie=UTF-8&amp;source=lnms&amp;tbm=shop&amp;sa=X&amp;ved=0ahUKEwin3uL0hqrsAhWWHbkGHRDoDc4Q_AUICCgB">Shopping</a>, <a class="eZt8xd" href="/search?q=lego&amp;ie=UTF-8&amp;source=lnms&amp;tbm=isch&amp;sa=X&amp;ved=0ahUKEwin3uL0hqrsAhWWHbkGHRDoDc4Q_AUICSgC">Imagens</a>, <a class="eZt8xd" href="/search?q=lego&amp;ie=UTF-8&amp;sourc
# ...

# %%
pagina.find_all(class_='news-titulo')
# Out:
# [<div class="news-titulo"><h1>Araçatuba tem aumento de 74% nos casos de covid-19 na semana</h1></div>,
#  <div class="news-titulo"><a href="/aracatuba/noticia/politica/lider-de-suposta-organizacao-criminosa-recebeu-titulo-de-cidadao-biriguiense" style="color:rgb(61, 133, 198);">Líder de suposta organização criminosa recebeu título de cidadão biriguiense</a></div>,
#  <div class="news-titulo"><a href="/aracatuba/noticia/economia/comercio-e-servicos-terao-horario-ampliado-a-partir-deste-sabado" style="color:rgb(120, 63, 4);">Comércio e serviços terão horário ampliado a partir deste sábado</a></div>,
#  <div class="news-titulo"><a href="/aracatuba/noticia/seu-negocio-aracatuba/colormaq-comemora-bom-momento-e-inaugura-barracao-reconstruido-apos-incendio" style="color:rgb(0, 0, 0);">Colormaq comemora bom momento e inaugura barracão reconstruído após incêndio</a></div>,
# ...

# %%
#coletar todos os links que uma página tem

links  = pagina.find_all('a',href=True)

# links  = pagina.find_all('a')
for link in links:
    print(link.get('href'))
# Out:
# https://g1.globo.com/
# https://g1.globo.com/loterias/
# http://g1.globo.com/economia/agronegocios/
# https://g1.globo.com/economia/agronegocios/
# https://g1.globo.com/economia/agronegocios/globo-rural/
# https://g1.globo.com/economia/agronegocios/agro-a-industria-riqueza-do-brasil/
# https://g1.globo.com/bemestar/
# https://g1.globo.com/bemestar/
# https://g1.globo.com/bemestar/coronavirus/
# https://g1.globo.com/bemestar/viva-voce/
# https://revistaautoesporte.globo.com/
# http://g1.globo.com/ciencia-e-saude/
# https://g1.globo.com/ciencia-e-saude/
# https://g1.globo.com/ciencia-e-saude/viva-voce/
# http://g1.globo.com/economia/concursos-e-emprego/
# http://g1.globo.com/economia/
# https://g1.globo.com/economia/
# http://g1.globo.com/economia/agronegocios/
# https://g1.globo.com/economia/agronegocios/
# https://g1.globo.com/economia/agronegocios/globo-rural/
# http://g1.globo.com/economia/seu-dinheiro/calculadoras/
# http://g1.globo.com/economia/concursos-e-emprego/
# ...

# %% [markdown]
# # Tendo os links que a página relaciona, podemos verificar cada um deles se tem alguma palavra interessante (do contexto) ?

# %% [markdown]
# # Para cada link encontrado, podemos quebrar o nome e verificar se o slug faz parte de um corpus relacionado ao tema buscado...
#
# por exemplo:   https://g1.globo.com/loterias/ tem a palavra loterias que é relacionado...  podemos fazer uma busca nesse link e verificar mais sobre o assunto...
